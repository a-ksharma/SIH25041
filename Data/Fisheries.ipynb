# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Fisheries.csv")
data
# Out:
#      ISSCAP CODE                Species Category  \
# 0           37.0        Caranx carangus       LD
# 1           34.0    Tachysurus serratus       LD
# 2           37.0        Caranx carangus       LD
# 3           37.0        Caranx carangus       LD
# 4           38.0  Carcharhinus limbatus       LD
# ..           ...                    ...      ...
# 639         57.0       Loligo duvauceli       CP
# 640         57.0       Loligo duvauceli       CP
# 641         57.0       Loligo duvauceli       CP
# 642         57.0       Loligo duvauceli       CP
# 643         57.0       Loligo duvauceli       CP
#
#                                              Source          Family   SpcID  \
# 0                    IJF 1992 39 (3,4) Reuben et al      CARANGIDAE     NaN
# 1                               Bull.40 CMFRI, 1987         ARIIDAE     NaN
# 2                           JMBA 1994,36(1&2) Kasim      CARANGIDAE     NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 644 entries, 0 to 643
# Data columns (total 61 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ISSCAP CODE        638 non-null    float64
#  1   Species            644 non-null    object
#  2   Category           644 non-null    object
#  3   Source             642 non-null    object
#  4   Family             644 non-null    object
#  5   SpcID              640 non-null    float64
#  6   StudyLocality      644 non-null    object
#  7   Region             644 non-null    object
#  8   StartYear          633 non-null    float64
#  9   EndYear            630 non-null    float64
#  10  Gear               623 non-null    object
#  11  GScore             644 non-null    float64
#  12  GRank              644 non-null    int64
#  13  Sex                636 non-null    object
#  14  K                  644 non-null    float64
#  15  KRank              644 non-null    int64
# ...

# %%
data.isnull().sum()
# Out:
# ISSCAP CODE     6
# Species         0
# Category        0
# Source          2
# Family          0
#                ..
# BLDRank         0
# CPI             0
# CPIRank         0
# PriceRank       0
# RankTotal      12
# Length: 61, dtype: int64

# %%
data.describe()
# Out:
#        ISSCAP CODE        SpcID    StartYear      EndYear      GScore  \
# count   638.000000   640.000000   633.000000   630.000000  644.000000
# mean     38.884013  2136.487500  1988.710900  1994.666667   11.463975
# std       6.958885  1533.809548    72.745004     9.053102    2.924574
# min      31.000000    48.000000   180.000000  1964.000000    4.500000
# 25%      34.000000  1181.000000  1984.000000  1988.000000    9.900000
# 50%      36.000000  1612.000000  1990.000000  1994.500000   11.700000
# 75%      42.000000  4033.000000  2000.000000  2002.000000   13.400000
# max      57.000000  5026.000000  2008.000000  2009.000000   17.600000
#
#             GRank           K       KRank           M            F  ...  \
# count  644.000000  644.000000  644.000000  643.000000   643.000000  ...
# mean     4.021739    0.961941    3.548137    1.559154     6.159054  ...
# std      1.259302    0.498522    1.402901    0.910355    81.982235  ...
# ...

# %%
data.value_counts("ISSCAP CODE")
# Out:
# ISSCAP CODE
# 34.0    192
# 37.0    124
# 45.0     84
# 35.0     61
# 57.0     59
# 36.0     56
# 38.0     18
# 42.0     16
# 31.0     10
# 33.0      8
# 43.0      5
# 47.0      3
# 56.0      2
# Name: count, dtype: int64
