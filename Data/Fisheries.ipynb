# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Fisheries.csv")

# %%
df.sample(5)
# Out:
#      ISSCAP CODE               Species Category  \
# 86          34.0        Saurida tumbil       LD
# 199         34.0  Nemipterus japonicus       SD
# 6           38.0   Carcharhinus sorrah       LD
# 262         34.0       Johnieops aneus       SD
# 642         57.0      Loligo duvauceli       CP
#
#                                              Source          Family   SpcID  \
# 86                        Sivakami et al 2009 unpub    SYNODONTIDAE   472.0
# 199  Trophic  Modelling of Arabian Sea of Karnataka    NEMIPTERIDAE  1367.0
# 6                                Kasim, AFSIB, 1996  CARCHARHINIDAE    52.0
# 262                Jayasankar 1997 IJMS 24: 153-157      SCIAENIDAE  1486.0
# 642                 Silas et al., CMFRI Bull.no. 37     LOLIGINIDAE  5026.0
#
#       StudyLocality Region  StartYear  EndYear  ...   Dist  DistRank   MTL  \
# 86           Cochin     SW     1993.0   1999.0  ...  82.00         6  4.14
# ...
